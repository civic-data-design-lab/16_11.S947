# %% [markdown]
# # Problem Set 2: Intro to Pandas

# %% [markdown]
# ## Part 1
#
# In this problem set we are going to be working with a processed O-D dataset, Pandas, and Matplotlib.
#
# First, a short example will introduce us to the dataset, some data wrangling functions of Pandas, and a few plots with Matplotlib.
# The OD data was collected based on cell phone towers. Usually, OD datasets are quite big, and contain individual data points, with origin-destination information between cell phone towers. In this case, the dataset has previously been aggregated and processed. While the text files are still very big, their size is significantly smaller than the original dataset.
# The files that follow the "Rn_OD_X-Y" naming structure contain the origin-destination flow from hour X to hour Y with the following columns:
#
# * Origin tower ID
# * Destination tower ID
# * Closest road intersection to origin
# * Closest intersection to destination
# * Origin-destination flow
#
# The file "towers_index.txt" contains the locations of all the cell towers with the following columns. The row number is the id of the cell tower starting with 1.
#
# * Latitude
# * Longitude
# * Node ID of the closest intersection to the tower
#
# Throughout the exercises we will be continuously using Pandas and some of its merging functionality to join the numerous OD files available. We will be building exploratory data visualizations, finding urban patterns and locating divergent areas within the dataset. Some useful documentation for merging data with Pandas can be found at:
#
#
# http://pandas.pydata.org/pandas-docs/stable/merging.html

# %% [markdown]
# First, lets import some of our libraries. If you haven't installed seaborn already, please type on your command line:
#
# ```Python
# pip install seaborn
# ```

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

# This line lets us plot on our ipython notebook
# %matplotlib inline

# %% [markdown]
# Let’s read one of the OD files with Pandas. Since the file has no header, we need to provide the header names. Luckily, we have all the information we need on the `DATA_STRUCTURES.txt` file.

# %%
df_01=pd.read_csv("data/Hourly Flows/Rn_OD_0-1.txt", header=None, 
               names=['oid', 'did', 'close_rid_origin', 'close_rid_dest', 'flow'])
df_01.head()
# Out:
#    oid  did  close_rid_origin  close_rid_dest  flow
# 0    1    2             20404           16208     1
# 1    1   20             20404           11056     3
# 2    1   38             20404           18943     6
# 3    1   42             20404           18961     3
# 4    1   60             20404           18942     2

# %% [markdown]
# We need to import every file with a separate function.
#
# `Hint: You can import multiple files with a for loop, or building a function, without having to declare them individually`

# %%
df_12=pd.read_csv("data/Hourly Flows/Rn_OD_1-2.txt", header=None, 
               names=['oid', 'did', 'close_rid_origin', 'close_rid_dest', 'flow'])

df_12.head()
# Out:
#    oid  did  close_rid_origin  close_rid_dest  flow
# 0    1   14             20404           18826     1
# 1    1   23             20404           16864     1
# 2    1   38             20404           18943     1
# 3    1   42             20404           18961     1
# 4    1   57             20404           18944     1

# %% [markdown]
# If you notice, the df structure of both files is similar. We can perform a SQL style join based on a column or index on either of the df’s. In this case, since the rest of the columns are the same, we are only keeping the flow column of the second df.
#
# `Hint: You can merge multiple files with a for loop, or building a function, without having to do so individually`

# %%
combined_flow = df_01.join(df_12['flow'], lsuffix='0-1', rsuffix='1-2')
combined_flow[:10]
# Out:
#    oid  did  close_rid_origin  close_rid_dest  flow0-1  flow1-2
# 0    1    2             20404           16208        1        1
# 1    1   20             20404           11056        3        1
# 2    1   38             20404           18943        6        1
# 3    1   42             20404           18961        3        1
# 4    1   60             20404           18942        2        1
# 5    1   73             20404           18940        2        1
# 6    1  105             20404           17765        1        1
# 7    1  146             20404           17594        1        1
# 8    1  201             20404           11322        1        1
# 9    1  230             20404           18892        1        2

# %% [markdown]
# We can visualize our newly merged tables with a basic area plot. This plot visualizes the flow within the cell phone towers throughout the 2 different time ranges. By slicing the dataset, we are only plotting some of the towers.

# %%
combined_flow[:5][['flow0-1', 'flow1-2']].transpose().plot(kind='area', stacked=False, 
                                                            legend=True, title='Tower Flows')

# %% [markdown]
# **Based on the code snippets, and your previous code your job is to build:**
#
# * A function that merges the 24 hour ranges into a single DataFrame. The function must have the following inputs/outputs:
#     1. Inputs:
#       1. A file path to extract the different files from
#       * A column name to merge into a single DataFrame
#       * A list of column names for the DataFrame
#     2. Outputs:
#       1. A DataFrame with the merged columns

# %%
#Add your code below:

#function to import all hourly data frames 
def imprt_dfs(filepath, mergeindex, colnames):
    #import first hour txt file to serve as base for full dataframe
    main_df = pd.read_csv(filepath + "Rn_OD_0-1.txt", header=None, 
               names= colnames)
    main_df = main_df[['oid','did','flow']]
    
    #loop through importing remaining txt files and merging with main dataframe
    for i in range(1,24):
        df_join = pd.read_csv(filepath+"Rn_OD_" + str(i) + "-" + str(i+1) + ".txt", header=None, names = colnames)    
        main_df = pd.merge(left=main_df, right=df_join[['oid','did','flow']], on=['oid', 'did'], how='outer', 
                           sort = True, suffixes=(str(i-1)+"-"+str(i), str(i)+"-"+str(i+1)))
    
    #return complete dataframe
    return main_df

full_df = imprt_dfs("data/Hourly Flows/", 0, ['oid', 'did', 'close_rid_origin', 'close_rid_dest', 'flow'])
full_df
# Out:
#          oid   did  flow0-1  flow1-2  flow2-3  flow3-4  flow4-5  flow5-6  \
# 0          1     2        1      NaN      NaN      NaN      NaN      NaN
# 1          1     4      NaN      NaN      NaN      NaN      NaN      NaN
# 2          1     5      NaN      NaN      NaN      NaN      NaN      NaN
# 3          1     6      NaN      NaN      NaN      NaN      NaN      NaN
# 4          1     7      NaN      NaN      NaN      NaN      NaN      NaN
# 5          1     8      NaN      NaN      NaN      NaN      NaN      NaN
# 6          1     9      NaN      NaN      NaN      NaN      NaN      NaN
# 7          1    10      NaN      NaN      NaN      NaN      NaN      NaN
# 8          1    12      NaN      NaN      NaN      NaN      NaN      NaN
# 9          1    13      NaN      NaN      NaN      NaN      NaN      NaN
# 10         1    14      NaN        1      NaN      NaN      NaN      NaN
# 11         1    18      NaN      NaN      NaN      NaN      NaN      NaN
# 12         1    19      NaN      NaN      NaN      NaN      NaN      NaN
# 13         1    20        3      NaN        1      NaN      NaN        1
# 14         1    22      NaN      NaN      NaN      NaN      NaN      NaN
# 15         1    23      NaN        1      NaN      NaN      NaN        1
# 16         1    24      NaN      NaN      NaN      NaN      NaN      NaN
# 17         1    25      NaN      NaN      NaN      NaN      NaN      NaN
# 18         1    26      NaN      NaN      NaN      NaN      NaN      NaN
# 19         1    27      NaN      NaN      NaN      NaN      NaN      NaN
# 20         1    28      NaN      NaN      NaN      NaN      NaN      NaN
# 21         1    29      NaN      NaN      NaN      NaN      NaN      NaN
# 22         1    30      NaN      NaN      NaN      NaN      NaN      NaN
# 23         1    31      NaN      NaN      NaN      NaN      NaN      NaN
# 24         1    32      NaN      NaN      NaN      NaN      NaN      NaN
# 25         1    34      NaN      NaN      NaN      NaN      NaN      NaN
# 26         1    36      NaN      NaN      NaN      NaN      NaN      NaN
# 27         1    37      NaN      NaN      NaN      NaN        1      NaN
# 28         1    38        6        1      NaN        1      NaN        4
# 29         1    40      NaN      NaN      NaN      NaN      NaN      NaN
# ...      ...   ...      ...      ...      ...      ...      ...      ...
# 476905  1712  1656      NaN      NaN      NaN      NaN      NaN      NaN
# 476906  1712  1658      NaN      NaN      NaN      NaN      NaN      NaN
# 476907  1712  1664      NaN      NaN      NaN      NaN      NaN      NaN
# 476908  1712  1668      NaN      NaN      NaN      NaN      NaN      NaN
# 476909  1712  1670      NaN      NaN      NaN      NaN      NaN      NaN
# 476910  1712  1673      NaN      NaN      NaN      NaN      NaN      NaN
# 476911  1712  1674      NaN      NaN      NaN      NaN      NaN      NaN
# 476912  1712  1679      NaN        1        1      NaN      NaN        1
# 476913  1712  1683      NaN      NaN      NaN      NaN      NaN      NaN
# 476914  1712  1684      NaN      NaN      NaN      NaN      NaN      NaN
# 476915  1712  1685      NaN      NaN      NaN      NaN      NaN      NaN
# 476916  1712  1688      NaN      NaN      NaN      NaN      NaN      NaN
# 476917  1712  1689      NaN      NaN      NaN      NaN      NaN      NaN
# 476918  1712  1691      NaN      NaN      NaN      NaN      NaN      NaN
# 476919  1712  1692      NaN      NaN      NaN      NaN      NaN      NaN
# 476920  1712  1693        2        2      NaN      NaN      NaN      NaN
# 476921  1712  1694      NaN      NaN      NaN      NaN      NaN      NaN
# 476922  1712  1695      NaN      NaN      NaN      NaN      NaN        1
# 476923  1712  1696        1        1        2      NaN      NaN        1
# 476924  1712  1697        1        2        1      NaN        2        3
# 476925  1712  1698        1      NaN      NaN      NaN      NaN      NaN
# 476926  1712  1699        5        2        1      NaN      NaN      NaN
# 476927  1712  1700      NaN      NaN      NaN      NaN      NaN      NaN
# 476928  1712  1701        2        1        1      NaN      NaN      NaN
# 476929  1712  1704      NaN      NaN      NaN      NaN      NaN      NaN
# 476930  1712  1706      NaN      NaN      NaN      NaN      NaN      NaN
# 476931  1712  1708      NaN      NaN      NaN      NaN      NaN      NaN
# 476932  1712  1709      NaN      NaN      NaN      NaN      NaN      NaN
# 476933  1712  1710      NaN      NaN      NaN      NaN      NaN      NaN
# 476934  1712  1711        3      NaN        2      NaN        1        2
#
#         flow6-7  flow7-8    ...      flow14-15  flow15-16  flow16-17  \
# 0           NaN      NaN    ...            NaN        NaN        NaN
# 1           NaN      NaN    ...            NaN        NaN        NaN
# 2           NaN      NaN    ...              1        NaN        NaN
# 3           NaN      NaN    ...              1          2        NaN
# 4             1        2    ...              1          2          2
# 5           NaN      NaN    ...            NaN          1          1
# 6           NaN      NaN    ...            NaN        NaN        NaN
# 7           NaN        1    ...            NaN          1          3
# 8           NaN      NaN    ...            NaN        NaN          1
# 9           NaN      NaN    ...            NaN        NaN          1
# 10          NaN      NaN    ...            NaN        NaN        NaN
# 11          NaN      NaN    ...              1          3          4
# 12          NaN      NaN    ...            NaN        NaN        NaN
# 13            7        8    ...             26         16         32
# 14          NaN      NaN    ...            NaN        NaN          1
# 15          NaN        2    ...              4          4          5
# 16          NaN        1    ...            NaN          2          2
# 17          NaN      NaN    ...            NaN        NaN          1
# 18          NaN      NaN    ...            NaN        NaN        NaN
# 19          NaN      NaN    ...              2          1        NaN
# 20          NaN      NaN    ...            NaN        NaN        NaN
# 21          NaN      NaN    ...            NaN        NaN          1
# 22          NaN      NaN    ...            NaN        NaN        NaN
# 23          NaN      NaN    ...            NaN        NaN        NaN
# 24          NaN      NaN    ...            NaN          2        NaN
# 25          NaN      NaN    ...            NaN        NaN          1
# 26          NaN      NaN    ...              1          1        NaN
# 27          NaN      NaN    ...            NaN        NaN        NaN
# 28            2       11    ...             30         44         52
# 29          NaN      NaN    ...            NaN        NaN          1
# ...         ...      ...    ...            ...        ...        ...
# 476905      NaN      NaN    ...            NaN          1        NaN
# 476906        1      NaN    ...              1          1        NaN
# 476907      NaN      NaN    ...              3        NaN        NaN
# 476908      NaN      NaN    ...            NaN          2          1
# 476909      NaN        1    ...            NaN          2        NaN
# 476910      NaN        1    ...              1        NaN          1
# 476911        1      NaN    ...            NaN          1        NaN
# 476912        1        1    ...              3          2          1
# 476913      NaN      NaN    ...            NaN        NaN        NaN
# 476914      NaN      NaN    ...              1        NaN        NaN
# 476915      NaN      NaN    ...            NaN        NaN          1
# 476916      NaN      NaN    ...            NaN        NaN        NaN
# 476917      NaN      NaN    ...            NaN        NaN        NaN
# 476918      NaN      NaN    ...              1        NaN        NaN
# 476919      NaN        1    ...            NaN          1        NaN
# 476920        1        8    ...             12          8         10
# 476921      NaN      NaN    ...              1        NaN          1
# 476922      NaN        1    ...              1          1        NaN
# 476923        5        6    ...             17          9          6
# 476924        3        4    ...             11          6          5
# 476925      NaN        1    ...              1        NaN        NaN
# 476926        2        3    ...              7          6          3
# 476927      NaN      NaN    ...            NaN        NaN        NaN
# 476928      NaN      NaN    ...              4          2        NaN
# 476929      NaN      NaN    ...            NaN        NaN        NaN
# 476930      NaN      NaN    ...            NaN          1          1
# 476931      NaN      NaN    ...            NaN        NaN          1
# 476932        2      NaN    ...            NaN        NaN        NaN
# 476933      NaN      NaN    ...            NaN        NaN        NaN
# 476934        3        1    ...             12          5          1
#
#         flow17-18  flow18-19  flow19-20  flow20-21  flow21-22  flow22-23  \
# 0             NaN        NaN        NaN        NaN        NaN        NaN
# 1               1        NaN        NaN        NaN        NaN          1
# 2               1        NaN        NaN        NaN        NaN        NaN
# 3               2        NaN        NaN        NaN        NaN        NaN
# 4               4        NaN          1          1        NaN        NaN
# 5             NaN        NaN        NaN        NaN        NaN        NaN
# 6             NaN        NaN        NaN        NaN        NaN        NaN
# 7               2          2          2        NaN        NaN          1
# 8             NaN        NaN        NaN        NaN        NaN        NaN
# 9             NaN          1          1        NaN        NaN        NaN
# 10              1          1        NaN        NaN        NaN        NaN
# 11              2        NaN        NaN        NaN        NaN        NaN
# 12            NaN        NaN        NaN        NaN        NaN        NaN
# 13             25         21          8         20         25         21
# 14            NaN        NaN          1        NaN        NaN        NaN
# 15              7          2          4          4          2        NaN
# 16            NaN        NaN        NaN          1          1        NaN
# 17            NaN        NaN          1        NaN          2        NaN
# 18            NaN        NaN        NaN        NaN          1        NaN
# 19              3          1        NaN        NaN        NaN        NaN
# 20            NaN        NaN        NaN        NaN        NaN        NaN
# 21            NaN        NaN        NaN        NaN        NaN        NaN
# 22            NaN        NaN        NaN        NaN        NaN        NaN
# 23            NaN        NaN        NaN        NaN        NaN        NaN
# 24            NaN        NaN        NaN        NaN        NaN        NaN
# 25            NaN        NaN        NaN        NaN        NaN        NaN
# 26              1        NaN        NaN          1        NaN        NaN
# 27            NaN        NaN        NaN        NaN        NaN        NaN
# 28             36         38         14         25         17          9
# 29              1        NaN        NaN        NaN        NaN        NaN
# ...           ...        ...        ...        ...        ...        ...
# 476905        NaN        NaN        NaN        NaN        NaN        NaN
# 476906        NaN        NaN        NaN        NaN          1        NaN
# 476907        NaN        NaN        NaN        NaN        NaN        NaN
# 476908        NaN        NaN        NaN        NaN        NaN        NaN
# 476909        NaN        NaN        NaN        NaN          1        NaN
# 476910          2          1        NaN        NaN        NaN          1
# 476911        NaN        NaN        NaN        NaN        NaN        NaN
# 476912          2        NaN          1          2          1        NaN
# 476913          2        NaN        NaN        NaN        NaN        NaN
# 476914        NaN        NaN        NaN        NaN        NaN        NaN
# 476915        NaN        NaN        NaN        NaN        NaN        NaN
# 476916        NaN        NaN        NaN        NaN        NaN        NaN
# 476917        NaN        NaN        NaN        NaN        NaN        NaN
# 476918        NaN        NaN        NaN        NaN        NaN        NaN
# 476919          1        NaN        NaN        NaN        NaN        NaN
# 476920          6          5          7          7          4          6
# 476921        NaN        NaN        NaN        NaN        NaN        NaN
# 476922        NaN        NaN          1        NaN          1        NaN
# 476923          4          6          4        NaN          8          2
# 476924          3          5          7          6          1          8
# 476925          1          3          1        NaN        NaN          1
# 476926          3          9          4        NaN          6          9
# 476927        NaN        NaN        NaN        NaN        NaN          1
# 476928        NaN          6        NaN          1          1          2
# 476929        NaN        NaN        NaN          1        NaN        NaN
# 476930          1        NaN          1        NaN        NaN          1
# 476931        NaN        NaN        NaN        NaN        NaN        NaN
# 476932        NaN          1        NaN        NaN        NaN        NaN
# 476933        NaN          1        NaN        NaN        NaN        NaN
# 476934          2          2          2          4          3          9
#
#         flow23-24
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13              6
# 14            NaN
# 15              1
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28              7
# 29            NaN
# ...           ...
# 476905        NaN
# 476906        NaN
# 476907        NaN
# 476908        NaN
# 476909        NaN
# 476910        NaN
# 476911        NaN
# 476912        NaN
# 476913        NaN
# 476914        NaN
# 476915        NaN
# 476916        NaN
# 476917        NaN
# 476918        NaN
# 476919        NaN
# 476920          1
# 476921        NaN
# 476922        NaN
# 476923          5
# 476924          2
# 476925        NaN
# 476926          1
# 476927        NaN
# 476928          1
# 476929        NaN
# 476930        NaN
# 476931        NaN
# 476932        NaN
# 476933        NaN
# 476934          4
#
# [476935 rows x 26 columns]

# %% [markdown]
# * Using all the towers: Make an area plot that shows the relationship between OD flows throughout the 24 hr ranges.

# %%
# Add your code below:

#Aggregate total OD flows by hour
plot_df = full_df[full_df.columns[2:]]
aggr_df = plot_df.sum().transpose() 

aggr_plot = aggr_df.plot(kind='area', stacked=False, legend=False, title='Total Flows by Hour')
aggr_plot.set_xlabel("Hours")
aggr_plot.set_ylabel("Total Hourly OD Flows")

#Aggregate by 10 busiest origin towers 
top10_df = full_df.groupby(full_df['oid']).sum()
top10_df = top10_df[top10_df.columns[2:]]
top10_df["sum"] = top10_df.sum(axis=1)
plottop10 = top10_df.nlargest(10, "sum")
top10plot = plottop10[plottop10.columns[:-1]].transpose().plot(kind='area', stacked=False, legend=True, 
                                                               title='Hourly Flows for 10 Busiest Origin Towers')
top10plot.set_xlabel("Hours")
top10plot.set_ylabel("Hourly OD Flows")

#Aggregate by 10 least busy origin towers 
btm10_df = full_df.groupby(full_df['oid']).sum()
btm10_df = btm10_df[btm10_df.columns[2:]]
btm10_df["sum"] = btm10_df.sum(axis=1)
plotbtm10 = btm10_df.nsmallest(10, "sum")
btm10plot = plotbtm10[plottop10.columns[:-1]].transpose().plot(kind='area', stacked=False, legend=True, 
                                                               title='Hourly Flows for 10 Least Busy Origin Towers')
btm10plot.set_xlabel("Hours")
btm10plot.set_ylabel("Hourly OD Flows")

# %% [markdown]
# ** Choose ONE of the following TWO questions.**
# * An area plot with **four** different areas:
#     1. The average flow values across **all** towers
#     2. The maximum flow values across **all** towers
#     3. The minimum flow values across **all** towers
#     4. The median flow values across **all** towers

# %%
# Add your code below:
#Assumption of summary statistics is that NaN values do not count as zero OD flow
summary_df = full_df[full_df.columns[2:]]
summary_df = summary_df.describe()
plot_df = summary_df.transpose()
plot1_df = plot_df[['min', '50%', 'mean', 'max']]
plot1 = plot1_df.plot(kind='area', stacked=False, legend=True, title='Total Flows by Hour')
plot1.set_xlabel("Hours")
plot1.set_ylabel("Hourly Flow")

#run second plot without max to make other 3 summary stats more visible
plot2_df = plot_df[['min', '50%', 'mean']]
plot2 = plot2_df.plot(kind='area', stacked=False, legend=True, title='Total Flows by Hour')
plot2.set_xlabel("Hours")
plot2.set_ylabel("Hourly Flow")

# %% [markdown]
# * Based on the overall trends that you just noticed with the previous plots, construct:
#     1. An area plot based on the values of 5 towers with flow values that are closer to the average trend.
#     2. An area plot based on the outlier values. You will plot 3 towers with flow values that are closer to the minimum trend, and towers with flow values that are closer to the maximum trend.

# %%
# Add your code below:

# %% [markdown]
# ## Part 2
#
# Now we will use the additional file provided to display the geographical location of every tower. We will first import the file and look at its structure. Since the file has no header, we will use the information provided on the `DATA_STRUCTURES.txt` file. The row number corresponds to the tower index; in order to relate every tower with the OD files, we will add an additional column with the row number as an index. We can do so with the following `DataFrame` function:
# ```Python
# DataFrame.reset_index(level=0, inplace=True)
# ```

# %%
towers=pd.read_csv("data/Hourly Flows/towers_index.txt", header=None, 
               names=['Latitude', 'Longitude', 'Closest node ID'])
# Use the row value as the index column
towers.reset_index(level=0, inplace=True)
towers.head()
# Out:
#    index  Latitude  Longitude  Closest node ID
# 0      0    24.517     46.776            20404
# 1      1    24.517     46.890            16208
# 2      2    24.517     46.890            16208
# 3      3    24.524     46.710            18805
# 4      4    24.525     46.648            11072

# %% [markdown]
# If you look at the structure of the OD file, every tower is repeated several times: for every origin tower, there are several destinations. In SQL terms, we can use a `one-to-many` relationship to assign the geographic values of the towers, to the origin or destination towers. By joining a `DataFrame` `on` a given column, Pandas will assign the row value of every element that matches the value of the given column on the other `DataFrame`. We will also group the origin values of the OD Dataframe, and get their average before joining it with the towers’ geographical location.

# %%
# from the OD df, use only two columns, then group them by 'oid'
grouped_01 = df_01[['flow','oid']].groupby('oid').mean()

# use the oid as a column, not the index
grouped_01.reset_index(level=0, inplace=True)

# join with the tower df based on the oid
OD_location = grouped_01.join(towers, on='oid')
OD_location.head()
# Out:
#    oid      flow  index  Latitude  Longitude  Closest node ID
# 0    1  1.846154      1    24.517     46.890            16208
# 1    3  1.000000      3    24.524     46.710            18805
# 2    4  1.111111      4    24.525     46.648            11072
# 3    5  1.166667      5    24.529     46.687            18825
# 4    6  1.307692      6    24.530     46.722            18736

# %% [markdown]
# Now that we have a new `DataFrame` with an average flow value for every origin tower, and their corresponding geographical location, we can use their lat/lon values to create a scatter plot. We can even vary their size based on the average flow. Since the flow variation across tower is not that big, we can use a log function to better visualize it on our plot. Numpy has a quick log implementation:
# ```Python
# np.log(value)
# ```

# %%
plt.scatter(OD_location['Longitude'],OD_location['Latitude'], s=np.log(OD_location['flow'])*100)
plt.show()

# %% [markdown]
# **Based on the code snippets, and your previous code your job is to build:**
#
# * A function that creates a [color range](http://matplotlib.org/users/colormaps.html) based on a `numpy array` of numeric values [(Example 1)](http://stackoverflow.com/questions/12965075/matplotlib-scatter-plot-colour-as-function-of-third-variable), [(Example 2)](http://stackoverflow.com/questions/11364745/how-can-i-turn-a-numpy-array-into-a-matplotlib-colormap). The function must have the following inputs/outputs:
#     1. Inputs:
#       1. A `numpy` `array` or a `Pandas DataSeries`
#       * Two different colors to interpolate values between.
#     2. Outputs:
#       1. A `numpy array` of `colors` or `color values`

# %%
# Add your code below:
test_ser = top10_df["sum"]

def color_range(inpt):
    scaled_inpt = (inpt - inpt.min()) / inpt.ptp()
    colors = plt.cm.plasma(scaled_inpt)
    return colors

test_colors = color_range(test_ser)
test_colors
# Out:
# array([[ 0.674522,  0.147419,  0.578688,  1.      ],
#        [ 0.075353,  0.027206,  0.538007,  1.      ],
#        [ 0.16407 ,  0.020171,  0.577478,  1.      ],
#        ...,
#        [ 0.132381,  0.022258,  0.56325 ,  1.      ],
#        [ 0.471457,  0.005678,  0.659897,  1.      ],
#        [ 0.299855,  0.009561,  0.631624,  1.      ]])

# %% [markdown]
# ### All the plots below should be scatter plots. Parameterize the size of the points to the obtained values.
#
# * A plot that visualizes the average flow values using the 24 hour ranges. Color the plots using the function to create the color array.
#     * The `Dataframe` must be grouped and averaged by 'oid'
#     * The flow values must be averaged across the 24 hr ranges. IE
#     ```Python
#     flow_ranges = [5, 5, 5, 5, 5, 5, 10, 10, 10, 10, 10, 10]
#     avg_flow = 7.5
#     ```

# %%
# Add your code below:
# group the df by origin tower and find mean accross 24 hour range
grp_01 = full_df.drop('did', axis=1).groupby('oid').sum()
grp_01['avg'] = grp_01.mean(axis=1)

# use the oid as a column, not the index
grp_01.reset_index(level=0, inplace=True)
grp_01 = grp_01[['oid','avg']]

w_twrs = pd.merge(left=grp_01, right=towers, left_on='oid', right_on='index', how='inner')
w_twrs

pl = plt.scatter(w_twrs['Longitude'], w_twrs['Latitude'], s=w_twrs['avg'],  color=color_range(w_twrs['avg']))
plt.title("Average OD Flow by Origin Tower")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# %% [markdown]
# * A plot that visualizes the maximum flow values using the 24 hour ranges. Color the plots using the function to create the color array.
#     * The `Dataframe` must be grouped by 'oid', you can then use these values to find the `max()`
#     * Use those flow values to find the `max()` across the 24 hr ranges. IE
#     ```Python
#     flow_ranges = [5, 5, 5, 5, 5, 5, 10, 10, 10, 10, 10, 100]
#     max_flow = 100
#     ```

# %%
# Add your code below:

# group the df by origin tower and find max accross 24 hour range
grp_02 = full_df.drop('did', axis=1).groupby('oid').sum()
grp_02['max'] = grp_02.max(axis=1)

# use the oid as a column, not the index
grp_02.reset_index(level=0, inplace=True)
grp_02 = grp_02[['oid','max']]

w_twrs2 = pd.merge(left=grp_02, right=towers, left_on='oid', right_on='index', how='inner')

plt.scatter(w_twrs2['Longitude'], w_twrs2['Latitude'], s=w_twrs2['max'], color=color_range(w_twrs2['max']))
plt.title("Maximum OD Flow by Origin Tower")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# %% [markdown]
# * A plot that visualizes the minimum flow values using the 24 hour ranges. Color the plots using the function to create the color array.
#     * The `Dataframe` must be grouped by 'oid', you can then use these values to find the `min()`
#     * Use those flow values to find the `min()` across the 24 hr ranges. IE
#     ```Python
#     flow_ranges = [5, 5, 5, 5, 5, 5, 10, 10, 10, 10, 10, 100]
#     min_flow = 5
#     ```

# %%
# Add your code below:

# group the df by origin tower and find max accross 24 hour range
grp_03 = full_df.drop('did', axis=1).groupby('oid').sum()
grp_03['min'] = grp_03.min(axis=1)

# reset the 
grp_03.reset_index(level=0, inplace=True)
grp_03 = grp_03[['oid','min']]

w_twrs3 = pd.merge(left=grp_03, right=towers, left_on='oid', right_on='index', how='inner')

plt.scatter(w_twrs3['Longitude'], w_twrs3['Latitude'], s=w_twrs3['min'], color=color_range(w_twrs3['min']))
plt.title("Minimum OD Flow by Origin Tower")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# %% [markdown]
# ## Graphic Presentation
# #### Make sure to label all the axis, add legends and units (where appropriate).
#
#
# ## Code Quality
# #### While code performance and optimization won't count, all the code should be highly readable, and reusable. Where possible, create functions, build helper functions where needed, and make sure the code is self-explanatory.
